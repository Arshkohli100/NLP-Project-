# %% [markdown]
# <a href="https://colab.research.google.com/github/Arshkohli100/NLP-Project-/blob/main/NLP_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
# !python Simple_chatbot.py
# Out:
# Hi, I'm Nova 🤖 — your friendly chatbot!
# You can chat with me in lowercase English. Type 'quit' to exit.
#
# >hi i am arshdeep
# Hey there! 😊
# >who made you
# I was created by Arshdeep, Manit, and Prem as part of their NLP mini-project 🧠
# >i am feeling happy
# Nice to meet you, feeling happy! What would you like to talk about?
# >where do you live
# I live in the cloud ☁️, but my creators are from India!
# >what sports do you like
# I’m a huge cricket fan! What about you?
# >football i like
# Got it! What else would you like to talk about?
# >nothing bye
# That’s interesting — tell me more.
# >bye
# It was fun talking to you! See you later 👋
# >object address  : 0x7d3d52257340
# object refcount : 3
# object type     : 0xa2a4e0
# object type name: KeyboardInterrupt
# object repr     : KeyboardInterrupt()
# lost sys.stderr
# ^C
